# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
WaterLevel = pd.read_csv("./dataset/WaterLevel.csv")
Rainfall = pd.read_csv("./dataset/RainFall.csv")
Target = pd.read_csv("./dataset/Target.csv")
Discharge = pd.read_csv("./dataset/Target_discharge.csv")

# %%
# 창녕함안보 수위 그래프
plt.plot(Target['Unnamed: 0'], Target['waterlevel'].values, color='r')
plt.show()

# %%
# 창녕함안보 총유입량 그래프
plt.plot(Target['Unnamed: 0'], Discharge['총유입량'].values, color='b')
plt.show()
